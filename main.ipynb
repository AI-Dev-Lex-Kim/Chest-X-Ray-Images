# %%
# %pip install import-ipynb
# %pip install koreanize-matplotlib
# %pip install omegaconf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 39.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=520ec8498c8cc9a68e22990a75e9af9b655d49cde993fd3793c5b46ce71233c2
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# ...

# %%
project_root = '/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/mission6'
train_cfg_path = f'{project_root}/configs/baseline.yaml'
inference_cfg_path = f'{project_root}/configs/inference.yaml'

# %%
from google.colab import drive, runtime
drive.mount('/content/drive')

import sys
sys.path.insert(0, project_root)

import import_ipynb

# 파일 로드
from scripts.train import run_train
from utils.helper import save_imgs_df
from utils.transforms import get_transform
from utils.data import data_split, create_loader
from utils.model import get_model
from utils.training_loop import set_seed, seed_worker, get_optimizer, train_one_epoch, evaluate_one_epoch
from utils.checkpoint import save_best_model_weight, save_hparam, save_loss_log
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-1b6c2c1ea5db> in <cell line: 0>()
#      13 from utils.data import data_split, create_loader
#      14 from utils.model import get_model
# ---> 15 from utils.training_loop import set_seed, seed_worker, get_optimizer, train_one_epoch, evaluate_one_epoch
#      16 from utils.checkpoint import save_best_model_weight, save_hparam, save_loss_log
#
# ImportError: cannot import name 'train_one_epoch' from 'utils.training_loop' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
import os
import csv

import koreanize_matplotlib
import time
import random
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from omegaconf import OmegaConf

import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import models
from torchvision.datasets import ImageFolder

# %%
# train 모드 실행

train_cfg = OmegaConf.load(train_cfg_path) # Load the config file
run_train(train_cfg)

# %%
runtime.unassign()
